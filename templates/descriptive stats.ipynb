# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\Niels\Desktop\Programming\Manifesting pasado programming\Datasets\Predictive Mainte\summarized.csv")

# %%
grouped = df.groupby('EQUIPMENT NAME')

# %%
frequency = grouped.size()
total_duration = grouped['TOTAL DURATION'].sum()
average_duration = grouped['TOTAL DURATION'].mean()
max_duration = grouped['TOTAL DURATION'].max()
min_duration = grouped['TOTAL DURATION'].min()

# %%
stats_df = pd.DataFrame({
    'Frequency': frequency,
    'Total Duration': total_duration,
    'Average Duration': average_duration,
    'Max Duration': max_duration,
    'Min Duration': min_duration
})

# %%
stats_df
# Out:
#                                         Frequency  Total Duration  \
# EQUIPMENT NAME
#  Acer Projector                                 1        6.500000
#  Arduino Kit                                    5       59.950000
#  Switch                                         1        1.750000
# (200, 3/8, 8, 4, 100, 16, 140, 50, 30)          1       20.166667
# 1 Manual/Book                                   1        1.283333
# ...                                           ...             ...
# hdmi, VGA, Extension                            1        3.666667
# measuring tape 100m                             2        0.566667
# pliers                                          1        0.750000
# switch                                          1        0.283333
# with probe - adaptor                            1        1.250000
#
#                                         Average Duration  Max Duration  \
# EQUIPMENT NAME
# ...

# %%
total_quantity.plot(kind='bar', title='Total Quantity Borrowed per Equipment')
plt.show()
avg_duration.plot(kind='bar', title='Average Duration of Borrowing per Equipment')
plt.show()
